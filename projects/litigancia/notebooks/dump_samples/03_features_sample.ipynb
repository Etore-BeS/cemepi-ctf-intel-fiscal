# %% [markdown]
# # Litigância 03 — Features sample

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)
# Out:
# extracao 2026 3 limit 100

# %%
deb=C.sample_dataset("debito",limit=S.sample_limit,
 select="ID_DEBITO,TIPO_DEBITO,SITUACAO_DEBITO,STATUS_AJUIZAMENTO_DEBITO,VALOR_SEM_HONORARIOS,ANO_EXTRACAO,MES_EXTRACAO",
 extra={"ANO_EXTRACAO":S.ano,"MES_EXTRACAO":S.mes})
deb.to_parquet(C.sample_dir()/"a3_debito_sample.parquet",index=False)
print(deb["TIPO_DEBITO"].value_counts().head())
# Out:
# TIPO_DEBITO
# IPVA               60
# ICMS Declarado     28
# Taxa Judiciária     8
# ICMS Autuação       2
# Multas              1
# Name: count, dtype: int64
