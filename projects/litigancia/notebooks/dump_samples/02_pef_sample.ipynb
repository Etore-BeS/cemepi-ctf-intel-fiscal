# %% [markdown]
# # Litigância 02 — PEF sample

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)
# Out:
# extracao 2026 3 limit 100

# %%
df=C.sample_dataset("ajuizamento",limit=S.sample_limit,select="ID_DEBITO,PEF,DT_AJUIZAMENTO,NOMECOMARCA")
df.to_parquet(C.sample_dir()/"a2_ajuizamento_sample.parquet",index=False)
print(df.head()); print("lake", S.lake_root.exists())
# Out:
#    ID_DEBITO                        PEF DT_AJUIZAMENTO  \
# 0   49534713  1500047-12.2016.8.26.0236     2016-10-17
# 1   49534721  1500004-47.2017.8.26.0040     2017-03-20
# 2   49534754  1500034-38.2016.8.26.0066     2016-10-19
# 3   49534787  1507794-97.2016.8.26.0014     2016-10-14
# 4   49534797  1630083-81.2016.8.26.0224     2016-05-16
#
#                                          NOMECOMARCA
# 0                                Comarca de Ibitinga
# 1                     Comarca de Américo Brasiliense
# 2                                Comarca de Barretos
# 3  Vara das Execuções Fiscais Estaduais da Comarc...
# 4                               Comarca de Guarulhos
# lake True
