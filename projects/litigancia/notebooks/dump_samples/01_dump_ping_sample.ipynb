# %% [markdown]
# # Litigância 01 — Dump ping

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)
# Out:
# extracao 2026 3 limit 100

# %%
import json
h=C.get_json("/health"); m=C.get_json("/meta/tabelas"); v=C.get_json("/v1/analytics/visao-geral")
print(h.get("status"), len(m.get("datasets",[])))
(C.sample_dir()/"a1_visao_geral.json").write_text(json.dumps({"status":h.get("status"),"qtd":v.get("estoque",{}).get("qtd_debitos")},indent=2),encoding="utf-8")
# Out:
# ok 9
# 38
