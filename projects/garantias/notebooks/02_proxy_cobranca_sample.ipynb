# %% [markdown]
# # Garantias 02 — Proxy

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)

# %%
parc=C.sample_dataset("parcelamento",limit=S.sample_limit); prot=C.sample_dataset("protesto",limit=S.sample_limit)
parc.to_parquet(C.sample_dir()/"d2_parcelamento_sample.parquet",index=False)
prot.to_parquet(C.sample_dir()/"d2_protesto_sample.parquet",index=False)
print(list(parc.columns)[:8])

# %% [markdown]
# ## Continuação
#
# EDA completo (população + amostra + figuras Plotly): [`playground/proxy_cobranca_eda_v0.ipynb`](playground/proxy_cobranca_eda_v0.ipynb).
