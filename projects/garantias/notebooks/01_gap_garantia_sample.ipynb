# %% [markdown]
# # Garantias 01 — Gap

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)
# Out:
# extracao 2026 3 limit 100

# %%
import json
names=[d["dataset"] for d in C.get_json("/meta/tabelas").get("datasets",[])]
assert "garantia" not in names
(C.sample_dir()/"d1_gap_garantia.json").write_text(json.dumps({"datasets":names,"garantia":False},indent=2),encoding="utf-8")
print(names)
# Out:
# ['ajuizamento', 'arrecadacao', 'debito', 'faturamento', 'ingest_log', 'ingest_rejects', 'parcelamento', 'protesto', 'receita']
