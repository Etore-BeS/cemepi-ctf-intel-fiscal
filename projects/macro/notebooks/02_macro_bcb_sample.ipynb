# %% [markdown]
# # Macro 02 — BCB

# %%
from pathlib import Path
import sys, os
NB_DIR = Path.cwd()
MONO = next((p for p in [NB_DIR, *NB_DIR.parents] if (p / "shared" / "cemepi_api").exists()), NB_DIR)
sys.path.insert(0, str(MONO))
os.chdir(MONO)
from shared.cemepi_api import CemepiClient, load_settings
S = load_settings(); C = CemepiClient(S)
print("extracao", S.ano, S.mes, "limit", S.sample_limit)
# Out:
# extracao 2026 3 limit 100

# %%
from bcb import sgs
m=sgs.get({"selic":432}, start="2024-01-01").join(sgs.get({"ipca":433}, start="2024-01-01"), how="outer")
m.to_parquet(C.sample_dir()/"c2_macro_sample.parquet"); print(m.tail())
# Out:
#             selic  ipca
# Date
# 2026-09-06   14.0   NaN
# 2026-09-07   14.0   NaN
# 2026-09-08   14.0   NaN
# 2026-09-09   14.0   NaN
# 2026-09-10   14.0   NaN
